# %%
from konlpy.tag import Kkma, Hannanum, Komoran, Mecab, Twitter
import sentencepiece as spm
import re
import string
from bs4 import BeautifulSoup
import urllib.request
import feedparser
import requests
from collections import defaultdict
from operator import itemgetter
from tqdm.notebook import tqdm
from itertools import product
import pandas as pd
import pickle

# %%
with open('./nate_newWord.pkl', 'rb') as f:
    words = pickle.load(f)
with open('./nate_preprocessed.pkl', 'rb') as f:
    sents = pickle.load(f)

# %%
def recover(tokens):
    sent = ''.join(tokens)
    sent = sent.replace('▁', ' ')
    return sent[1:]

def example_of_word (sents, words, idx = None, by_word = None, N = 15):
    if by_word is not None:
        word = by_word
        print(f'Target word: {word}')
        print(f'Word in new word list: {word in words}')
    elif idx is not None:
        word = words[idx]
        print(f'Target word: {word}')
    
    answer = []
    cowords = defaultdict(int)
    for sent in sents:
        comparable = list(map(lambda x: x.replace('▁', ''), sent))
        if word in comparable:
            answer.append(recover(sent))
            for w in comparable:
                cowords[w] += 1
    print(f'TOTAL SENTENCES: {len(answer)}')
    sorted_cowords = list(map(lambda x: x[0], sorted(cowords.items(), key = itemgetter(1), reverse = True)))
    new_cowords = {w : cowords[w] for w in sorted_cowords if w in words and w != word}
    TopN = dict(sorted(new_cowords.items(), key=itemgetter(1), reverse=True)[:N])
    print(f'TOP {N} NEAR NEW WORDS: {TopN}')
    return answer

# %%
result = example_of_word(sents, words, by_word = '페이커')
# Out:
# Target word: 페이커
# Word in new word list: False
# TOTAL SENTENCES: 0
# TOP 15 NEAR NEW WORDS: {}

# %%
import json
with open('senti_info.json', encoding='utf-8-sig', mode='r') as f:
    data = json.load(f)
with open('abusivewords.txt', 'r', encoding='UTF-8') as f:
    wikidata = list(map(lambda x: x.replace('\n',''), f.readlines()))

def word_polarity(wordname):
    result = None
    if data.get(wordname):
        return int(data[wordname])
    return result

from collections import Counter
def sent_with_new_word (sents, word):
    '''
    sents: 문장 모음.
    word: 타겟으로 하는 신조어
    '''
    answer = []
    for sent in sents:
        comparable = list(map(lambda x: x.replace('▁', ''), sent))
        if word in comparable:
            answer += comparable
    return Counter(answer)

def is_slang(word):
    for w in wikidata:
        if w in word:
            return -3
    return None

def new_word_sentiment (word):
    point_sum = []
    cnt = 0
    samples = sent_with_new_word(sents, word)
    for w in list(samples):
        point1 = word_polarity(w)
        point2 = is_slang(w)
        
        if point2:
            point = point2
        elif point1:
            point = point1
        else:
            point = None
        
        if point:
            point_sum.append(point * samples[w])
            cnt += samples[w]
    if cnt:
        return sum(point_sum) / cnt
    return None

# %%
scores = {}
for word in tqdm(words):
    score = new_word_sentiment(word)
    if score:
        scores[word] = score
        tqdm.write('{}: {}'.format(word, scores[word]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=454.0), HTML(value='')))
# 는거: -1.0476190476190477
# 그랬: -1.5681818181818181
# 모르겠: -1.2380952380952381
# 이였: -1.3095238095238095
# 갑수목장: -0.6666666666666666
# 지않: -1.0
# 찾아봤: -1.0
# 비어있: -2.0
# 들한테: -2.0
# 관심없: -1.3076923076923077
# 실망하: -0.6666666666666666
# 리니까: -2.0
# 나봐: -1.3333333333333333
# 소름돋: -0.2857142857142857
# 쁘단: -1.0
# 은듯: -1.0
# 개극혐: -2.5
# 라짐: -2.3333333333333335
# 다보니: -1.0714285714285714
# 욕심안내고: -2.4285714285714284
# 좋겠: -0.5
# 았어: -2.5
# 전체적으: -2.0
# 좋겠당: 2.0
# 챙겼: -1.8888888888888888
# 안챙기: -1.5714285714285714
# 기로했: 1.0
# 정떨어: -3.0
# 해놓: -2.0
# 기억하: -0.8666666666666667
# 결혼하: -1.0
# 었습니다: -1.4388888888888889
# 숨겼: -3.0
# 않았습니: -1.125925925925926
# 고있습니다: -2.5
# 것같: -1.2
# 고싶은데: -0.5
# 게된: -2.0
# 무시하: -1.8333333333333333
# 조롱하: -1.8333333333333333
# 임ᄋᄋ: -1.8333333333333333
# 얘기하: -1.5
# 려서: -0.5
# 중고딩: 2.0
# 학년때: -3.0
# 져있: -0.6470588235294118
# 끝났: -2.0
# 망했: -2.5
# 죽고싶: -3.0
# 공개하: -1.3333333333333333
# ᄋᄌᄅ임: -1.2
# 틀딱: -1.0
# 어놓고: -1.0
# 다녔: -1.28125
# 했겠: -2.769230769230769
# 받고싶: -2.769230769230769
# 깊티: -0.08333333333333333
# 고마웡: -0.4
# 퍼가지마: -0.4
# 안챙: -0.4
# 거야ᄉᄇ: -0.4
# 설렜: -0.4
# 같이쓰: -0.4
# 설레ᅲᅲᅲᅲ: 0.3333333333333333
# 개설렌다: -2.0
# 와씨: -0.5
# 개설레: -3.0
# 었을까: -1.5
# 거같음: -0.75
# 어야함: -0.5
# 징그: 1.0
# ᄋᄌᄅ하: 1.0
# 트도: -2.0
# 통보하: -2.0
# 안끼: -1.5
# ᄏᄏ진짜: 0.5
# 싸이쿨: -0.3333333333333333
# 당하셨는: 1.0
# 감사하: 1.0
# 셨을: -0.5
# 줘ᅲᅲ: -0.5
# 물화생지: -0.75
# 겁니: -1.3972602739726028
# 잘가르치셔: 1.0
# 강의하: 0.3333333333333333
# 되셨: 1.0
# 잘맞: 1.2
# 웹드에: -1.5
# nn: -3.0
# 웹드: -2.3333333333333335
# 개웃기네: -3.0
# 가틈: -2.0
# 좋았: -2.75
# 어놨: -3.0
# 였으면: -0.25
# 초등학: -1.2421052631578948
# 이쁘장: 2.0
# 해보이: -2.0
# 냉미남: 1.5
# 거같: -0.9090909090909091
# 릴듯: -3.0
# 생겻: 1.0
# 존예: 1.1666666666666667
# 존잘: 1.4166666666666667
# 나같: -1.0
# 당했: -2.3333333333333335
# 역겨: -0.5
# 밑댓: -1.4
# 침묵하: -2.0
# 할수있: -0.5
# 바꼇: 1.0
# 이많: 1.0
# 승마살이: -2.0
# 올렸: -0.9285714285714286
# 오진다: -1.3333333333333333
# 는건: -1.542857142857143
# 몸매좋: -3.0
# 판녀들: 0.38461538461538464
# 함ᄏᄏ: -2.75
# 는거임: 0.125
# 물어봤: -0.6666666666666666
# 던거: 1.0
# 찾았: -3.0
# 렸어: -1.4375
# 안했: -3.0
# 는건데: -1.0
# 입었: -3.0
# 을거같은: -3.0
# 런바지: -2.0
# 빵상자에다: -1.5
# 났었: -1.4285714285714286
# 쪽팔: 0.5
# 포기하: -0.6
# 쳐먹: -2.0
# 겠음: -2.6666666666666665
# 죽겠: -0.9285714285714286
# 겠네: -3.0
# 안오: -3.0
# 나봄: -0.75
# 딩들: 1.5
# 는거같: -2.0
# 꺼지라: -2.6666666666666665
# 르겠음: 2.0
# 못받: -2.5
# 추천받: 0.25
# 하셨: -1.2460732984293195
# 거같아: 0.125
# 퇴하: -0.5503355704697986
# 고민하: -1.2894736842105263
# 한직업: 1.5
# 넘었: -1.0
# 연결해놓: -1.0
# 럴까: -1.4
# 저랬: -1.2
# 끄러워: 1.0
# 통화하: -1.5
# 고싶다고: -1.5
# 헤어졌: -1.8
# 싫을거같: 2.0
# 안좋: -0.5
# 어딨: 1.1666666666666667
# 닌데: -2.0
# 부럽네: -3.0
# 단호하: -0.8372093023255814
# 었어요: -2.0
# 귓말: 0.16666666666666666
# 느꼈: -1.4545454545454546
# 립니다: -2.0
# 쪽팔리: -1.75
# 매장시켜버: -1.25
# 뿌려진다: -0.8
# 끊어버: -1.0
# 삭제하: -2.0
# 뿌렸: -2.0
# 릴거: -0.25
# 말했: -1.3
# 할거같: -3.0
# 고싶고: 2.0
# 고싶어: -1.0
# 색하: -1.25
# 의심하: -1.1666666666666667
# 는거아님: -3.0
# 롱하: -1.4705882352941178
# 개표인: -1.2857142857142858
# 개ᄉᄁ: -1.2857142857142858
# 대깨문: -3.0
# 겠습니: -1.279742765273312
# 았는데: -1.5294117647058822
# 가입하: -1.3095238095238095
# 주셨: -1.3191489361702127
# 드리겠: -1.411764705882353
# 행복하시: -0.4
# 만나시길: 1.75
# 궁금했: 2.0
# 성혼률: -1.4285714285714286
# 겼는데: -1.4
# 임신했: -1.4
# 임테기: -1.2352941176470589
# 닌까: -1.4
# 열흘뒤에: -1.4
# 인줄알았: -1.588235294117647
# 안먹: -1.4
# 울었: -1.2876712328767124
# 먹고싶: -1.4705882352941178
# 고싶더라: -1.4
# 큐ᅲᅲ: -1.1578947368421053
# ᄏ큐ᅲ: -1.4
# 줄거같: -1.1666666666666667
# 에따라: -1.8
# Go: -1.6666666666666667
# ou: -2.5714285714285716
# pl: -1.4166666666666667
# vers: -2.5714285714285716
# ns: -0.5
# ity: -2.1923076923076925
# cr: -2.0
# nter: -1.9
# ine: -1.6666666666666667
# 국가정: -1.65
# 필요없: -1.5
# ᄏᄏ나: -1.5
# 겠네요: 2.0
# 려구: -3.0
# 릴게요: 1.0
# 야되는: 1.75
# 쳐늙어: -2.75
# 새꺄: -2.25
# 봅니: 2.0
# 두셨: 0.6666666666666666
# 얼마안: -3.0
# ter: -1.8461538461538463
# BCI: -1.65
# MK: -1.65
# 들더: -1.65
# NS: -1.368421052631579
# 웃으: 0.19047619047619047
# 지만그: -0.48
# 놓았: 1.0
# 2): -1.1470588235294117
# 숙해: -1.512
# 선택하: 1.0
# 폭발하: 2.0
# gi: -1.2777777777777777
# 후회하: 0.25
# 블핑: -1.2352941176470589
# 시켰: -1.0714285714285714
# 빡쳐: -1.0
# 드렸: -1.25
# 보냈: -1.2571428571428571
# 안받: -2.0
# 는소리: -2.0
# 고싶지않: -0.5
# 수술하: -2.0
# 는날: -0.6666666666666666
# 안보이: -0.2857142857142857
# 시더라고요: -1.6666666666666667
# 1): -0.9259259259259259
# 3): -0.9259259259259259
# 4): -0.9259259259259259
# 남겼: -0.3170731707317073
# 게임하: -2.5
# 은건: -2.5
# 는건가: -1.2727272727272727
# 을려: -1.2727272727272727
# 생각했: -1.2727272727272727
# 래그런: -0.8
# 자였: -0.8
# 로좀: -0.6666666666666666
# 는줄: -1.0
# 보고있: -1.0
# 9): -0.9655172413793104
# 유튜: -1.0
# 걸으: -1.3580246913580247
# 선포하: -1.16
# 찍으: -0.85
# 살사바: -0.5
# 이니까: -0.5882352941176471
# 짖으: -1.6666666666666667
# 6): -1.2142857142857142
# 7): 1.0
# WCC: -1.8717948717948718
# eli: -1.4166666666666667
# ous: -1.4166666666666667
# nc: -1.5238095238095237
# eti: -1.4166666666666667
# sm: -1.2857142857142858
# ori: -1.4166666666666667
# ri: -1.4166666666666667
# issio: -1.8064516129032258
# Dei: -1.8064516129032258
# ue: -1.6666666666666667
# va: -1.6666666666666667
# uth: -1.6666666666666667
# Church: -2.4
# ed: -2.4
# 강조하: -2.4
# 주문하: -2.4
# ial: -2.4
# pel: -2.4
# ph: -2.4
# 개설레ᅲᅲ: -1.6666666666666667
# 다ᅲ: 0.3333333333333333
# 다정하: 0.625
# 네ᅲ: -3.0
# 개설렌: -3.0
# 엑소팬: 0.6666666666666666
# 엑소엘: -0.42857142857142855
# 스밍: 1.75
# 임ᄏᄏ: -2.0
# 웃기넼ᄏᄏ: -2.3333333333333335
# 타팬인: 1.5
# 개현타: -0.7142857142857143
# 뷔백현: 0.75
# 웃겼: 1.0
# 은것: 1.0
# 웃기냐: -1.0
# 입고있: -2.0
# 다ᅮ: -1.0
# 블레앚: 2.0
# 트와팬들: -1.25
# 도높은: -2.2
# 안시키: -2.2
# 다암ᄋᄋ: -2.2
# 았냐: -2.2
# 럽이: -2.2
# 러들: -2.0
# 모모꼬: -1.6666666666666667
# 개빡: -3.0
# 치겠: -3.0
# 이클: -2.727272727272727

# %%
with open('nate_scores.pkl', 'wb') as f:
    pickle.dump(scores, f)

# %%
with open('dc_iu_scores.pkl', 'rb') as f:
    lol_scores = pickle.load(f)
n = sorted(lol_scores.items(), key = (lambda x:x[1]))
with open('dc_iu_sorted_scores.txt', 'w', encoding = 'utf-8') as f:
    for w, s in n:
        f.write(w+': '+str(s)+'\n')

# %%
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-102-9f670460cd62> in <module>
#       1 with open('dc_lol_sorted_scores.pkl', 'rb') as f:
# ----> 2     n = pickle.load(f)
#       3 with open('dc_lol_sorted_scores.txt', 'w') as f:
#       4     for w in n:
#       5         f.write(w+': '+n[w]+'\n')
#
# EOFError: Ran out of input

# %%
with open('dc_iu_scores.pkl', 'rb') as f:
    iu_scores = pickle.load(f)
sorted(iu_scores.items(), key = (lambda x:x[1]))
with open('dc_iu_scores.txt', 'rb') as f:
    f.write(iu_scores)
# Out:
# [('미친', -3.0),
#  ('보소', -3.0),
#  ('MV', -3.0),
#  ('이드', -3.0),
#  ('가즈아', -3.0),
#  ('개추', -3.0),
#  ('좋겠다', -3.0),
#  ('ost', -3.0),
#  ('됐다', -3.0),
#  ('나의', -3.0),
#  ('저씨', -3.0),
#  ('몇개', -3.0),
#  ('넣어', -3.0),
#  ('xt', -3.0),
#  ('빠졌네요', -3.0),
#  ('해석해봄', -3.0),
#  ('실화냐', -3.0),
#  ('잘만', -3.0),
#  ('일시후원', -3.0),
#  ('는거지', -3.0),
#  ('안뇽', -3.0),
#  ('는건', -3.0),
#  ('첫댓글', -3.0),
#  ('바람직', -3.0),
#  ('존나', -3.0),
#  ('없었', -3.0),
#  ('개쩔어', -3.0),
#  ('해봤음', -3.0),
#  ('어그로', -3.0),
#  ('개띵곡', -3.0),
#  ('좋네', -3.0),
#  ('EDAM', -3.0),
#  ('세계최', -3.0),
#  ('위키', -3.0),
#  ('우리유', -2.6666666666666665),
#  ('했던', -2.6),
#  ('움짤', -2.5),
#  ('jpg', -2.5),
#  ('팔레트', -2.5),
#  ('챗셔', -2.5),
#  ('ed', -2.5),
#  ('알아', -2.466666666666667),
#  ('충격이', -2.466666666666667),
#  ('개독회사에서', -2.4444444444444446),
#  ('낫다하하하', -2.4444444444444446),
#  ('먹어라', -2.4444444444444446),
#  ('하십시요', -2.4444444444444446),
#  ('적극홍보', -2.4444444444444446),
#  ('것들', -2.4285714285714284),
#  ('디어', -2.4285714285714284),
#  ('정신차려', -2.4285714285714284),
#  ('부탁합니다ᅳᅳᅳᅳᅳ', -2.4285714285714284),
#  ('걸린', -2.4130434782608696),
#  ('심하다', -2.4),
#  ('GS', -2.4),
#  ('만드', -2.4),
#  ('똘아', -2.4),
#  ('개독회사', -2.4),
#  ('올려주시', -2.4),
#  ('불매', -2.4),
#  ('운동합시다', -2.4),
#  ('공부하자', -2.4),
#  ('올려주세요', -2.388888888888889),
#  ('심한', -2.382978723404255),
#  ('합시다', -2.382978723404255),
#  ('지랄이다', -2.380952380952381),
#  ('장이', -2.3636363636363638),
#  ('잘한다', -2.3636363636363638),
#  ('회장이', -2.3529411764705883),
#  ('인증글', -2.3333333333333335),
#  ('종교차별', -2.3333333333333335),
#  ('지랄한다', -2.3333333333333335),
#  ('바랍니다', -2.3333333333333335),
#  ('나는', -2.3214285714285716),
#  ('종교자유', -2.3137254901960786),
#  ('필독하자', -2.3),
#  ('일하는', -2.290909090909091),
#  ('확인하', -2.289855072463768),
#  ('강제개종', -2.289855072463768),
#  ('개독', -2.287878787878788),
#  ('부탁합니다', -2.2745098039215685),
#  ('유튜브에', -2.2666666666666666),
#  ('똥목사', -2.245614035087719),
#  ('웃긴다', -2.245614035087719),
#  ('유튜브', -2.2),
#  ('필독', -2.2),
#  ('말하', -2.2),
#  ('한다', -2.1666666666666665),
#  ('불쌍하다', -2.1607142857142856),
#  ('적극홍보합시다', -2.0952380952380953),
#  ('불매운동합시다', -2.0833333333333335),
#  ('올려주', -2.0833333333333335),
#  ('이다', -2.0660377358490565),
#  ('네이버', -2.064516129032258),
#  ('구글', -2.064516129032258),
#  ('필독하고', -2.0634920634920637),
#  ('지말', -2.029850746268657),
#  ('원하는', -2.0),
#  ('퇴근하고', -2.0),
#  ('집콕시그널', -2.0),
#  ('팬아트', -2.0),
#  ('는건가', -2.0),
#  ('박스옹', -2.0),
#  ('해야', -2.0),
#  ('감사합니다', -2.0),
#  ('주관적', -2.0),
#  ('있겠', -2.0),
#  ('안녕하세요', -2.0),
#  ('있습니다', -2.0),
#  ('글로', -2.0),
#  ('했는데', -2.0),
#  ('해라', -2.0),
#  ('징하네', -2.0),
#  ('된듯', -2.0),
#  ('러브포엠', -2.0),
#  ('짐승호', -2.0),
#  ('매니', -2.0),
#  ('일체유심조', -2.0),
#  ('차별하', -2.0),
#  ('입니', -2.0),
#  ('아트레이아', -2.0),
#  ('퍄퍄퍄퍄퍄ᅣ', -2.0),
#  ('퍄ᅣ', -2.0),
#  ('있네', -2.0),
#  ('봅시다', -2.0),
#  ('찾아', -2.0),
#  ('qe', -2.0),
#  ('빤스목사', -2.0),
#  ('검색해', -2.0),
#  ('하는', -1.9307692307692308),
#  ('방탄소년단', -1.8888888888888888),
#  ('입니다', -1.8571428571428572),
#  ('자들', -1.8571428571428572),
#  ('사람이', -1.8518518518518519),
#  ('정신차려라', -1.85),
#  ('거임', -1.8333333333333333),
#  ('적인', -1.8333333333333333),
#  ('나만', -1.8),
#  ('일이', -1.8),
#  ('똘아이', -1.8),
#  ('필요하다', -1.8),
#  ('아닐것', -1.8),
#  ('없다', -1.7142857142857142),
#  ('흘러', -1.7142857142857142),
#  ('시요', -1.7142857142857142),
#  ('있으', -1.6666666666666667),
#  ('인들이', -1.6666666666666667),
#  ('사탄이', -1.6666666666666667),
#  ('해주세요', -1.6),
#  ('음싸', -1.6),
#  ('스포티파이', -1.6),
#  ('만들어', -1.5454545454545454),
#  ('잘보', -1.5),
#  ('겠지', -1.5),
#  ('하다', -1.4615384615384615),
#  ('어나', -1.4444444444444444),
#  ('근데', -1.4),
#  ('있음', -1.375),
#  ('좋은날', -1.3333333333333333),
#  ('태양의', -1.3333333333333333),
#  ('같은', -1.3333333333333333),
#  ('디시', -1.3333333333333333),
#  ('인데', -1.3333333333333333),
#  ('브이', -1.3333333333333333),
#  ('슈가는', -1.3333333333333333),
#  ('노잼', -1.3333333333333333),
#  ('시간에', -1.2857142857142858),
#  ('댓글', -1.25),
#  ('양심불', -1.25),
#  ('보였', -1.25),
#  ('있는', -1.2307692307692308),
#  ('알려', -1.2),
#  ('내려', -1.1538461538461537),
#  ('아닌', -1.1428571428571428),
#  ('하면', -1.1111111111111112),
#  ('빠짐', -1.0),
#  ('IU', -1.0),
#  ('크나', -1.0),
#  ('델루나', -1.0),
#  ('블루밍', -1.0),
#  ('스포', -1.0),
#  ('했습니다', -1.0),
#  ('피부톤', -1.0),
#  ('없어', -1.0),
#  ('쳐라', -1.0),
#  ('기를', -1.0),
#  ('란다', -1.0),
#  ('rr', -1.0),
#  ('스밍이', -1.0),
#  ('봉갤러', -1.0),
#  ('대경고', -1.0),
#  ('것이다', -1.0),
#  ('것이', -1.0),
#  ('생각이', -0.95),
#  ('했다', -0.9285714285714286),
#  ('좋은일', -0.8333333333333334),
#  ('관점에', -0.8),
#  ('올렸는데', -0.8),
#  ('계속해', -0.75),
#  ('들어', -0.7272727272727273),
#  ('하게', -0.6875),
#  ('아이유와', -0.5833333333333334),
#  ('보면', -0.5714285714285714),
#  ('트렌', -0.5),
#  ('그려', -0.5),
#  ('에있는', -0.5),
#  ('몰라', -0.5),
#  ('Gr', -0.5),
#  ('같아', -0.5),
#  ('니당', -0.5),
#  ('주셔', -0.5),
#  ('갤에', -0.5),
#  ('왔는데', -0.5),
#  ('올리고', -0.5),
#  ('박서준', -0.5),
#  ('보이는', -0.5),
#  ('해줘', -0.5),
#  ('그렇다고', -0.5),
#  ('지붕킥', -0.5),
#  ('없으', -0.5),
#  ('ve', -0.42857142857142855),
#  ('MB', -0.4),
#  ('너랑나', -0.4),
#  ('고마워', -0.375),
#  ('분들', -0.3333333333333333),
#  ('읽어', -0.3333333333333333),
#  ('인스타', -0.3333333333333333),
#  ('렇게', -0.3333333333333333),
#  ('ou', -0.3333333333333333),
#  ('이트', -0.3333333333333333),
#  ('가져', -0.3333333333333333),
#  ('팬들', -0.3333333333333333),
#  ('아이유님', -0.2962962962962963),
#  ('아이유', -0.2948717948717949),
#  ('러워', -0.25),
#  ('는거', -0.25),
#  ('새로운', -0.25),
#  ('고마', -0.2),
#  ('되었', -0.2),
#  ('합니다', 0.25),
#  ('마음을', 0.25),
#  ('아이유님이', 0.25),
#  ('오마이걸', 0.25),
#  ('모르겠', 0.25),
#  ('나줘', 0.3333333333333333),
#  ('태어', 0.3333333333333333),
#  ('시작했', 0.3333333333333333),
#  ('아니라', 0.4),
#  ('위에', 0.5),
#  ('받은', 0.5),
#  ('유애나', 0.5555555555555556),
#  ('갤주', 1.0),
#  ('애나', 1.0),
#  ('동참합니다', 1.0),
#  ('글이라', 1.0),
#  ('려볼', 1.0),
#  ('징짱', 1.0),
#  ('Teaser', 1.0),
#  ('사진추가', 1.0),
#  ('SUGA', 1.0),
#  ('되는', 1.0),
#  ('rke', 1.0),
#  ('Ha', 1.0),
#  ('ze', 1.0),
#  ('eet', 1.0),
#  ('nsh', 1.0),
#  ('ine', 1.0),
#  ('nt', 1.0),
#  ('wh', 1.0),
#  ('sp', 1.0),
#  ('lov', 1.0),
#  ('ch', 1.0),
#  ('ight', 1.0),
#  ('예뻐', 1.0),
#  ('소액이', 1.0),
#  ('나오죠', 1.0),
#  ('없겠', 1.0),
#  ('놓고', 1.0),
#  ('만들었', 1.0),
#  ('돈이', 1.0),
#  ('뭐야', 1.0),
#  ('동참했', 1.0),
#  ('올라', 1.0),
#  ('봉갤', 1.0),
#  ('지으니어스', 1.0),
#  ('스밍리스트', 1.0),
#  ('나왔', 1.0),
#  ('투표해', 1.0),
#  ('퍄퍄', 1.0),
#  ('스트', 1.0),
#  ('싸워', 1.0),
#  ('대중이', 1.0),
#  ('준다', 1.0),
#  ('사랑입니다', 1.0),
#  ('건강검진', 1.0),
#  ('마음이', 1.0),
#  ('정리함', 1.0),
#  ('대단하', 1.0),
#  ('했네', 1.0),
#  ('일날', 1.0),
#  ('멜론차트', 1.0),
#  ('쳇셔', 1.0),
#  ('깍궁', 1.0),
#  ('안되는', 1.0),
#  ('팬질', 1.0),
#  ('사랑둥이들', 1.0),
#  ('빠져', 1.0),
#  ('happ', 1.2),
#  ('콜라보', 1.25),
#  ('리기', 1.25),
#  ('해봤', 1.25),
#  ('아니지만', 1.25),
#  ('드려요', 1.3333333333333333),
#  ('드립니다', 1.3333333333333333),
#  ('올렸', 1.3333333333333333),
#  ('작은', 1.3333333333333333),
#  ('BTS', 1.4),
#  ('좋아', 1.4),
#  ('팬이', 1.4),
#  ('갤주님', 1.5),
#  ('좋은거', 1.5),
#  ('이뻐요', 1.5),
#  ('이네', 1.5),
#  ('날이라고', 1.6666666666666667),
#  ('갑니다', 1.6666666666666667),
#  ('사랑해', 1.6666666666666667),
#  ('해요', 1.6666666666666667),
#  ('좋은', 1.7272727272727273),
#  ('사랑해요', 1.75),
#  ('징짱이', 2.0),
#  ('졸귀다', 2.0),
#  ('고갑니다', 2.0),
#  ('하네', 2.0),
#  ('디씨', 2.0),
#  ('눈팅하', 2.0),
#  ('해봅니당', 2.0),
#  ('날도', 2.0),
#  ('기부했어', 2.0),
#  ('넘어갔', 2.0),
#  ('었는데', 2.0),
#  ('좋다', 2.0),
#  ('고싶다', 2.0)]

# %%
with open('nate_scores.pkl', 'rb') as f:
    lol_scores = pickle.load(f)
sorted(lol_scores.items(), key = (lambda x:x[1]))
# Out:
# [('정떨어', -3.0),
#  ('숨겼', -3.0),
#  ('학년때', -3.0),
#  ('죽고싶', -3.0),
#  ('개설레', -3.0),
#  ('nn', -3.0),
#  ('개웃기네', -3.0),
#  ('어놨', -3.0),
#  ('릴듯', -3.0),
#  ('몸매좋', -3.0),
#  ('찾았', -3.0),
#  ('안했', -3.0),
#  ('입었', -3.0),
#  ('을거같은', -3.0),
#  ('겠네', -3.0),
#  ('안오', -3.0),
#  ('부럽네', -3.0),
#  ('할거같', -3.0),
#  ('는거아님', -3.0),
#  ('대깨문', -3.0),
#  ('려구', -3.0),
#  ('얼마안', -3.0),
#  ('네ᅲ', -3.0),
#  ('개설렌', -3.0),
#  ('개빡', -3.0),
#  ('치겠', -3.0),
#  ('했겠', -2.769230769230769),
#  ('받고싶', -2.769230769230769),
#  ('좋았', -2.75),
#  ('함ᄏᄏ', -2.75),
#  ('쳐늙어', -2.75),
#  ('이클', -2.727272727272727),
#  ('겠음', -2.6666666666666665),
#  ('꺼지라', -2.6666666666666665),
#  ('ou', -2.5714285714285716),
#  ('vers', -2.5714285714285716),
#  ('개극혐', -2.5),
#  ('았어', -2.5),
#  ('고있습니다', -2.5),
#  ('망했', -2.5),
#  ('못받', -2.5),
#  ('게임하', -2.5),
#  ('은건', -2.5),
#  ('욕심안내고', -2.4285714285714284),
#  ('Church', -2.4),
#  ('ed', -2.4),
#  ('강조하', -2.4),
#  ('주문하', -2.4),
#  ('ial', -2.4),
#  ('pel', -2.4),
#  ('ph', -2.4),
#  ('라짐', -2.3333333333333335),
#  ('웹드', -2.3333333333333335),
#  ('당했', -2.3333333333333335),
#  ('웃기넼ᄏᄏ', -2.3333333333333335),
#  ('새꺄', -2.25),
#  ('도높은', -2.2),
#  ('안시키', -2.2),
#  ('다암ᄋᄋ', -2.2),
#  ('았냐', -2.2),
#  ('럽이', -2.2),
#  ('ity', -2.1923076923076925),
#  ('비어있', -2.0),
#  ('들한테', -2.0),
#  ('리니까', -2.0),
#  ('전체적으', -2.0),
#  ('해놓', -2.0),
#  ('게된', -2.0),
#  ('끝났', -2.0),
#  ('개설렌다', -2.0),
#  ('트도', -2.0),
#  ('통보하', -2.0),
#  ('가틈', -2.0),
#  ('해보이', -2.0),
#  ('침묵하', -2.0),
#  ('승마살이', -2.0),
#  ('런바지', -2.0),
#  ('쳐먹', -2.0),
#  ('는거같', -2.0),
#  ('닌데', -2.0),
#  ('었어요', -2.0),
#  ('립니다', -2.0),
#  ('삭제하', -2.0),
#  ('뿌렸', -2.0),
#  ('cr', -2.0),
#  ('안받', -2.0),
#  ('는소리', -2.0),
#  ('수술하', -2.0),
#  ('임ᄏᄏ', -2.0),
#  ('입고있', -2.0),
#  ('러들', -2.0),
#  ('nter', -1.9),
#  ('챙겼', -1.8888888888888888),
#  ('WCC', -1.8717948717948718),
#  ('ter', -1.8461538461538463),
#  ('무시하', -1.8333333333333333),
#  ('조롱하', -1.8333333333333333),
#  ('임ᄋᄋ', -1.8333333333333333),
#  ('issio', -1.8064516129032258),
#  ('Dei', -1.8064516129032258),
#  ('헤어졌', -1.8),
#  ('에따라', -1.8),
#  ('쪽팔리', -1.75),
#  ('Go', -1.6666666666666667),
#  ('ine', -1.6666666666666667),
#  ('시더라고요', -1.6666666666666667),
#  ('짖으', -1.6666666666666667),
#  ('ue', -1.6666666666666667),
#  ('va', -1.6666666666666667),
#  ('uth', -1.6666666666666667),
#  ('개설레ᅲᅲ', -1.6666666666666667),
#  ('모모꼬', -1.6666666666666667),
#  ('국가정', -1.65),
#  ('BCI', -1.65),
#  ('MK', -1.65),
#  ('들더', -1.65),
#  ('인줄알았', -1.588235294117647),
#  ('안챙기', -1.5714285714285714),
#  ('그랬', -1.5681818181818181),
#  ('는건', -1.542857142857143),
#  ('았는데', -1.5294117647058822),
#  ('nc', -1.5238095238095237),
#  ('숙해', -1.512),
#  ('얘기하', -1.5),
#  ('었을까', -1.5),
#  ('안끼', -1.5),
#  ('웹드에', -1.5),
#  ('빵상자에다', -1.5),
#  ('통화하', -1.5),
#  ('고싶다고', -1.5),
#  ('필요없', -1.5),
#  ('ᄏᄏ나', -1.5),
#  ('롱하', -1.4705882352941178),
#  ('먹고싶', -1.4705882352941178),
#  ('느꼈', -1.4545454545454546),
#  ('었습니다', -1.4388888888888889),
#  ('렸어', -1.4375),
#  ('났었', -1.4285714285714286),
#  ('성혼률', -1.4285714285714286),
#  ('pl', -1.4166666666666667),
#  ('eli', -1.4166666666666667),
#  ('ous', -1.4166666666666667),
#  ('eti', -1.4166666666666667),
#  ('ori', -1.4166666666666667),
#  ('ri', -1.4166666666666667),
#  ('드리겠', -1.411764705882353),
#  ('밑댓', -1.4),
#  ('럴까', -1.4),
#  ('겼는데', -1.4),
#  ('임신했', -1.4),
#  ('닌까', -1.4),
#  ('열흘뒤에', -1.4),
#  ('안먹', -1.4),
#  ('고싶더라', -1.4),
#  ('ᄏ큐ᅲ', -1.4),
#  ('겁니', -1.3972602739726028),
#  ('NS', -1.368421052631579),
#  ('걸으', -1.3580246913580247),
#  ('나봐', -1.3333333333333333),
#  ('공개하', -1.3333333333333333),
#  ('오진다', -1.3333333333333333),
#  ('주셨', -1.3191489361702127),
#  ('이였', -1.3095238095238095),
#  ('가입하', -1.3095238095238095),
#  ('관심없', -1.3076923076923077),
#  ('말했', -1.3),
#  ('고민하', -1.2894736842105263),
#  ('울었', -1.2876712328767124),
#  ('개표인', -1.2857142857142858),
#  ('개ᄉᄁ', -1.2857142857142858),
#  ('sm', -1.2857142857142858),
#  ('다녔', -1.28125),
#  ('겠습니', -1.279742765273312),
#  ('gi', -1.2777777777777777),
#  ('는건가', -1.2727272727272727),
#  ('을려', -1.2727272727272727),
#  ('생각했', -1.2727272727272727),
#  ('보냈', -1.2571428571428571),
#  ('매장시켜버', -1.25),
#  ('색하', -1.25),
#  ('드렸', -1.25),
#  ('트와팬들', -1.25),
#  ('하셨', -1.2460732984293195),
#  ('초등학', -1.2421052631578948),
#  ('모르겠', -1.2380952380952381),
#  ('임테기', -1.2352941176470589),
#  ('블핑', -1.2352941176470589),
#  ('6)', -1.2142857142857142),
#  ('것같', -1.2),
#  ('ᄋᄌᄅ임', -1.2),
#  ('저랬', -1.2),
#  ('의심하', -1.1666666666666667),
#  ('줄거같', -1.1666666666666667),
#  ('선포하', -1.16),
#  ('큐ᅲᅲ', -1.1578947368421053),
#  ('2)', -1.1470588235294117),
#  ('않았습니', -1.125925925925926),
#  ('다보니', -1.0714285714285714),
#  ('시켰', -1.0714285714285714),
#  ('는거', -1.0476190476190477),
#  ('지않', -1.0),
#  ('찾아봤', -1.0),
#  ('쁘단', -1.0),
#  ('은듯', -1.0),
#  ('결혼하', -1.0),
#  ('틀딱', -1.0),
#  ('어놓고', -1.0),
#  ('나같', -1.0),
#  ('는건데', -1.0),
#  ('넘었', -1.0),
#  ('연결해놓', -1.0),
#  ('끊어버', -1.0),
#  ('고싶어', -1.0),
#  ('빡쳐', -1.0),
#  ('는줄', -1.0),
#  ('보고있', -1.0),
#  ('유튜', -1.0),
#  ('웃기냐', -1.0),
#  ('다ᅮ', -1.0),
#  ('9)', -0.9655172413793104),
#  ('올렸', -0.9285714285714286),
#  ('죽겠', -0.9285714285714286),
#  ('1)', -0.9259259259259259),
#  ('3)', -0.9259259259259259),
#  ('4)', -0.9259259259259259),
#  ('거같', -0.9090909090909091),
#  ('기억하', -0.8666666666666667),
#  ('찍으', -0.85),
#  ('단호하', -0.8372093023255814),
#  ('뿌려진다', -0.8),
#  ('래그런', -0.8),
#  ('자였', -0.8),
#  ('거같음', -0.75),
#  ('물화생지', -0.75),
#  ('나봄', -0.75),
#  ('개현타', -0.7142857142857143),
#  ('갑수목장', -0.6666666666666666),
#  ('실망하', -0.6666666666666666),
#  ('물어봤', -0.6666666666666666),
#  ('는날', -0.6666666666666666),
#  ('로좀', -0.6666666666666666),
#  ('져있', -0.6470588235294118),
#  ('포기하', -0.6),
#  ('이니까', -0.5882352941176471),
#  ('퇴하', -0.5503355704697986),
#  ('좋겠', -0.5),
#  ('고싶은데', -0.5),
#  ('려서', -0.5),
#  ('와씨', -0.5),
#  ('어야함', -0.5),
#  ('셨을', -0.5),
#  ('줘ᅲᅲ', -0.5),
#  ('역겨', -0.5),
#  ('할수있', -0.5),
#  ('안좋', -0.5),
#  ('ns', -0.5),
#  ('고싶지않', -0.5),
#  ('살사바', -0.5),
#  ('지만그', -0.48),
#  ('엑소엘', -0.42857142857142855),
#  ('고마웡', -0.4),
#  ('퍼가지마', -0.4),
#  ('안챙', -0.4),
#  ('거야ᄉᄇ', -0.4),
#  ('설렜', -0.4),
#  ('같이쓰', -0.4),
#  ('행복하시', -0.4),
#  ('싸이쿨', -0.3333333333333333),
#  ('남겼', -0.3170731707317073),
#  ('소름돋', -0.2857142857142857),
#  ('안보이', -0.2857142857142857),
#  ('였으면', -0.25),
#  ('릴거', -0.25),
#  ('깊티', -0.08333333333333333),
#  ('는거임', 0.125),
#  ('거같아', 0.125),
#  ('귓말', 0.16666666666666666),
#  ('웃으', 0.19047619047619047),
#  ('추천받', 0.25),
#  ('후회하', 0.25),
#  ('설레ᅲᅲᅲᅲ', 0.3333333333333333),
#  ('강의하', 0.3333333333333333),
#  ('다ᅲ', 0.3333333333333333),
#  ('판녀들', 0.38461538461538464),
#  ('ᄏᄏ진짜', 0.5),
#  ('쪽팔', 0.5),
#  ('다정하', 0.625),
#  ('두셨', 0.6666666666666666),
#  ('엑소팬', 0.6666666666666666),
#  ('뷔백현', 0.75),
#  ('기로했', 1.0),
#  ('징그', 1.0),
#  ('ᄋᄌᄅ하', 1.0),
#  ('당하셨는', 1.0),
#  ('감사하', 1.0),
#  ('잘가르치셔', 1.0),
#  ('되셨', 1.0),
#  ('생겻', 1.0),
#  ('바꼇', 1.0),
#  ('이많', 1.0),
#  ('던거', 1.0),
#  ('끄러워', 1.0),
#  ('릴게요', 1.0),
#  ('놓았', 1.0),
#  ('선택하', 1.0),
#  ('7)', 1.0),
#  ('웃겼', 1.0),
#  ('은것', 1.0),
#  ('존예', 1.1666666666666667),
#  ('어딨', 1.1666666666666667),
#  ('잘맞', 1.2),
#  ('존잘', 1.4166666666666667),
#  ('냉미남', 1.5),
#  ('딩들', 1.5),
#  ('한직업', 1.5),
#  ('타팬인', 1.5),
#  ('만나시길', 1.75),
#  ('야되는', 1.75),
#  ('스밍', 1.75),
#  ('좋겠당', 2.0),
#  ('중고딩', 2.0),
#  ('이쁘장', 2.0),
#  ('르겠음', 2.0),
#  ('싫을거같', 2.0),
#  ('고싶고', 2.0),
#  ('궁금했', 2.0),
#  ('겠네요', 2.0),
#  ('봅니', 2.0),
#  ('폭발하', 2.0),
#  ('블레앚', 2.0)]
